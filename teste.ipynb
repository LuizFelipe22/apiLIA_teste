# %%
import pandas as pd

from app.bd.conexao_bd import create_engine

from sqlalchemy import text

# %%
with create_engine().connect() as connection:

    result = connection.execute(text("""show tables"""))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/venv/lib/python3.8/site-packages/pymysql/connections.py:644, in Connection.connect(self, sock)
#     643 try:
# --> 644     sock = socket.create_connection(
#     645         (self.host, self.port), self.connect_timeout, **kwargs
#     646     )
#     647     break
#
# File /usr/lib/python3.8/socket.py:808, in create_connection(address, timeout, source_address)
#     807 try:
# --> 808     raise err
#     809 finally:
#     810     # Break explicitly a reference cycle
#
# File /usr/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
for i in result:
    print(i)
# Out:
# (55347179, '41273591', 'CASSIO APARECIDO LOPES 06457523803', '2135', '50', 1000.0, 'MICRO EMPRESA', None)

# %%
for i in result:
    print(i)
# Out:
# ('cnaes',)
# ('empresas',)
# ('estabelecimentos',)
# ('fiscal',)
# ('motivos_situacao_empresa',)
# ('municipios',)
# ('naturezas_juridicas',)
# ('paises',)
# ('qualificacoes_socios',)

# %%
from app.servicos.read_db import read_estabelecimento, read_estabelecimento_nome

tet = read_estabelecimento_nome('23035415000104')

for i in tet:
    print(i)
# Out:
# mysql+pymysql://root:my-secret-lia-pw@54.157.201.226:3306/empresa
# 23035415000104
# [<Fiscal>, <Fiscal>, <Fiscal>, <Fiscal>, <Fiscal>, <Fiscal>, <Fiscal>, <Fiscal>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/luiz/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/home/luiz/%C3%81rea%20de%20Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from app.servicos.read_db import read_estabelecimento, read_estabelecimento_nome
#       <a href='vscode-notebook-cell:/home/luiz/%C3%81rea%20de%20Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> tet = read_estabelecimento_nome('23035415000104')
# ...

# %%
# Out:
# mysql+pymysql://root:my-secret-lia-pw@54.157.201.226:3306/empresa
# 27865757006569
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/venv/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/venv/lib/python3.8/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# ...

# %%
from app.bd.conexao_bd import create_engine

pd.read_sql("""SELECT * FROM empresa.estabelecimentos WHERE MATCH(NM_FANTASIA, CNPJ)
                                      AGAINST('23035415000104' IN NATURAL LANGUAGE MODE) limit 200""", con=create_engine())
# Out:
# mysql+pymysql://root:my-secret-lia-pw@54.157.201.226:3306/empresa
#          ID            CNPJ CNPJ_BASICO CNPJ_ORDEM CNPJ_DV ID_MATRIZ_FILIAL  \
# 0  12858690  23035415000104    23035415       0001      04                1
#
#   NM_FANTASIA SITU_CADASTRAL DT_SITU_CADASTRAL MT_SITU_CADASTRAL  ... DDD1  \
# 0  METROPOLES              2        2015-08-07                00  ...   61
#
#   TELEFONE1  DDD2 TELEFONE2 DDD_FAX       FAX         CORREIO_ELETRONICO  \
# 0  32131700  None      None      61  32131700  FINANCEIRO@METROPOLES.COM
#
#   SITUACAO_ESPECIAL DT_SITU_ESPECIAL  HASH
# 0              None             None  None
#
# [1 rows x 31 columns]

# %%
texto = """SELECT * FROM empresa.estabelecimentos WHERE MATCH(NM_FANTASIA, CNPJ)
                                      AGAINST('Rede Globo' IN NATURAL LANGUAGE MODE)"""
pd.read_sql(texto, create)
# Out:
#   Cell In[21], line 1
#     import app.bd.conexao_bd import create_engine
#                              ^
# SyntaxError: invalid syntax

# %%
from app.servicos.read_db import read_estabelecimento, read_estabelecimento_nome

read_estabelecimento_nome('globo')
# Out:
# ---------------------------------------------------------------------------
# UnboundExecutionError                     Traceback (most recent call last)
# /home/luiz/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/home/luiz/%C3%81rea%20de%20Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> from app.servicos.read_db import read_estabelecimento, read_estabelecimento_nome
# ----> <a href='vscode-notebook-cell:/home/luiz/%C3%81rea%20de%20Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> read_estabelecimento_nome('globo')
#
# File ~/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/app/servicos/read_db.py:92, in read_estabelecimento_nome(nome)
#      89 def read_estabelecimento_nome(nome: str):
#      91     with create_session() as session:
# ...

# %%
for i in teste:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# UnboundExecutionError                     Traceback (most recent call last)
# /home/luiz/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/home/luiz/%C3%81rea%20de%20Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> for i in teste:
#       <a href='vscode-notebook-cell:/home/luiz/%C3%81rea%20de%20Trabalho/faculdade/ProjetoLIA/API/empresasbr/teste.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>     print(i)
#
# File ~/Área de Trabalho/faculdade/ProjetoLIA/API/empresasbr/venv/lib/python3.8/site-packages/sqlalchemy/orm/query.py:2833, in Query.__iter__(self)
#    2832 def __iter__(self) -> Iterator[_T]:
# -> 2833     result = self._iter()
#    2834     try:
#    2835         yield from result  # type: ignore
#
# ...
